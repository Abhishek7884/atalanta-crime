# ...                           ...
# 270658  POINT(-84.40118 33.68114)
# 270659  POINT(-84.46475 33.75592)
# 270660   POINT(-84.33122 33.7312)
# 270661  POINT(-84.39376 33.73656)
# 270662  POINT(-84.37225 33.77066)
# 270663   POINT(-84.3885 33.71283)
# 270664   POINT(-84.37025 33.8103)
# 270665  POINT(-84.38733 33.75391)
# 270666  POINT(-84.50762 33.68242)
# 270667  POINT(-84.38741 33.87706)
# 270668   POINT(-84.5299 33.68609)
# 270669  POINT(-84.42299 33.72133)
# 270670  POINT(-84.49864 33.76866)
# 270671  POINT(-84.34904 33.84895)
# 270672  POINT(-84.40793 33.76615)
# 270673  POINT(-84.40102 33.74844)
# 270674  POINT(-84.36212 33.84676)
# 270675     POINT(-84.51026 33.74)
# 270676   POINT(-84.4477 33.77555)
# 270677   POINT(-84.44465 33.7738)
# 270678  POINT(-84.40905 33.74805)
# 270679    POINT(-84.41532 33.767)
# 270680  POINT(-84.36817 33.67202)
# 270681  POINT(-84.35274 33.78328)
# 270682  POINT(-84.38777 33.79184)
# 270683  POINT(-84.34741 33.73927)
# 270684  POINT(-84.40013 33.70436)
# 270685  POINT(-84.44204 33.64068)
# 270686    POINT(-84.326 33.75374)
# 270687  POINT(-84.48138 33.75399)
#
# [270688 rows x 11 columns]

# %%
data2.head()
# Out:
#    column_a                 crime       number        date  \
# 0         0   LARCENY-NON VEHICLE  103040029.0  31-10-2010
# 1         1            AUTO THEFT  103040061.0  31-10-2010
# 2         2  LARCENY-FROM VEHICLE  103040169.0  31-10-2010
# 3         3            AUTO THEFT  103040174.0  31-10-2010
# 4         4   LARCENY-NON VEHICLE  103040301.0  31-10-2010
#
#                                   location   beat        neighborhood npu  \
# 0                         610 SPRING ST NW  509.0            Downtown   M
# 1                            850 OAK ST SW  401.0            West End   T
# 2                1344 METROPOLITAN PKWY SW  301.0  Capitol View Manor   X
# 3                         1752 PRYOR RD SW  307.0      Betmar LaVilla   Y
# 4  JOHN WESLEY DOBBS AVE NE / CORLEY ST NE  604.0     Old Fourth Ward   M
#
#         lat      long                 location_2
# 0  33.77101 -84.38895  POINT(-84.38895 33.77101)
# 1  33.74057 -84.41680   POINT(-84.4168 33.74057)
# 2  33.71803 -84.40774  POINT(-84.40774 33.71803)
# 3  33.70731 -84.39674  POINT(-84.39674 33.70731)
# 4  33.75947 -84.36626  POINT(-84.36626 33.75947)

# %%
data2.describe()
data2.columns
# Out:
# Index(['column_a', 'crime', 'number', 'date', 'location', 'beat',
#        'neighborhood', 'npu', 'lat', 'long', 'location_2'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# column_a          int64
# crime            object
# number          float64
# date             object
# location         object
# beat            float64
# neighborhood     object
# npu              object
# lat             float64
# long            float64
# location_2       object
# dtype: object

# %%
data2.isnull().sum()
# Out:
# column_a            0
# crime               0
# number              0
# date                0
# location            2
# beat                3
# neighborhood    11760
# npu              2096
# lat                 0
# long                0
# location_2          0
# dtype: int64

# %%
features = data2.iloc[:,:].values
features
# Out:
# array([[0, 'LARCENY-NON VEHICLE', 103040029.0, ..., 33.77101, -84.38895,
#         'POINT(-84.38895 33.77101)'],
#        [1, 'AUTO THEFT', 103040061.0, ..., 33.74057, -84.4168,
#         'POINT(-84.4168 33.74057)'],
#        [2, 'LARCENY-FROM VEHICLE', 103040169.0, ..., 33.71803, -84.40774,
#         'POINT(-84.40774 33.71803)'],
#        ...,
#        [270685, 'LARCENY-NON VEHICLE', 92448045.0, ...,
#         33.640679999999996, -84.44204, 'POINT(-84.44204 33.64068)'],
#        [270686, 'LARCENY-NON VEHICLE', 92440866.0, ..., 33.75374,
#         -84.32600000000001, 'POINT(-84.326 33.75374)'],
#        [270687, 'HOMICIDE', 92440372058.0, ..., 33.75399, -84.48138,
#         'POINT(-84.48138 33.75399)']], dtype=object)

# %%
labels = data2.iloc[:,1].values
labels
# Out:
# array(['LARCENY-NON VEHICLE', 'AUTO THEFT', 'LARCENY-FROM VEHICLE', ...,
#        'LARCENY-NON VEHICLE', 'LARCENY-NON VEHICLE', 'HOMICIDE'],
#       dtype=object)

# %%
data2.corr()
# Out:
#           column_a    number      beat       lat      long
# column_a  1.000000 -0.000428 -0.000401 -0.004370 -0.001070
# number   -0.000428  1.000000 -0.014538 -0.017205 -0.014103
# beat     -0.000401 -0.014538  1.000000 -0.267315  0.356970
# lat      -0.004370 -0.017205 -0.267315  1.000000  0.281592
# long     -0.001070 -0.014103  0.356970  0.281592  1.000000

# %%
data2.cov()
# Out:
#               column_a        number          beat           lat          long
# column_a  6.106022e+09 -2.261499e+11 -5.338452e+03 -1.555171e+01 -3.954212e+00
# number   -2.261499e+11  4.581780e+19 -1.674646e+10 -5.303398e+06 -4.515176e+06
# beat     -5.338452e+03 -1.674646e+10  2.895887e+04 -2.071584e+00  2.873174e+00
# lat      -1.555171e+01 -5.303398e+06 -2.071584e+00  2.073888e-03  6.065357e-04
# long     -3.954212e+00 -4.515176e+06  2.873174e+00  6.065357e-04  2.237110e-03

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['column_a'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['number'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['beat'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['lat'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['long'].hist(bins=10)

# %%
data2=data2.drop(['neighborhood','npu','crime','location','date','location_2',],axis=1)
data2
# Out:
#         column_a        number   beat       lat      long
# 0              0  1.030400e+08  509.0  33.77101 -84.38895
# 1              1  1.030401e+08  401.0  33.74057 -84.41680
# 2              2  1.030402e+08  301.0  33.71803 -84.40774
# 3              3  1.030402e+08  307.0  33.70731 -84.39674
# 4              4  1.030403e+08  604.0  33.75947 -84.36626
# 5              5  1.030403e+08  205.0  33.82838 -84.40133
# 6              6  1.030403e+08  410.0  33.70537 -84.45498
# 7              7  1.030404e+08  410.0  33.70121 -84.45724
# 8              8  1.030404e+08  201.0  33.83193 -84.42627
# 9              9  1.030404e+08  509.0  33.76040 -84.38746
# 10            10  1.030404e+08  602.0  33.76309 -84.35160
# [270688 rows x 5 columns]

# %%
df1=pd.DataFrame(data2)
cols=['column_a', 'number', 'beat',
        'lat', 'long' ]
df1[cols] = df1[cols].fillna(df1.mean().iloc[0])

# %%
df1.isnull().sum()
# Out:
# column_a    0
# number      0
# beat        0
# lat         0
# long        0
# dtype: int64

# %%
_=plt.scatter(df1['column_a'],df1['number'],  color='black')
_=plt.title('column_a vs number')
_=plt.xlabel('column_a')
_=plt.ylabel('number')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['column_a'],df1['beat'],  color='black')
_=plt.title('column_a vs beat')
_=plt.xlabel('column_a')
_=plt.ylabel('beat')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['column_a'],df1['lat'],  color='black')
_=plt.title('column_a vs lat')
_=plt.xlabel('column_a')
_=plt.ylabel('lat')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['column_a'],df1['long'],  color='black')
_=plt.title('column_a vs long')
_=plt.xlabel('column_a')
_=plt.ylabel('long')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['number'],df1['long'],  color='black')
_=plt.title('number vs long')
_=plt.xlabel('number')
_=plt.ylabel('long')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column='column_a')

# %%
df1.boxplot(column='long')

# %%
df1.boxplot(column='beat')

# %%
df1.boxplot(column='number')

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
sns.distplot(df1['long'])
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df1['lat'])

# %%
sns.distplot(df1['beat'])

# %%
sns.distplot(df1['number'])

# %%
sns.distplot(df1['column_a'])

# %%
x=df1.iloc[:,1]

y=df1.iloc[:,-1]

# %%
x_var=df1['column_a']
y_var=df1[ 'number']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 number   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     972.8
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):          3.51e-213
# Time:                        17:59:34   Log-Likelihood:            -6.5114e+06
# No. Observations:              270688   AIC:                         1.302e+07
# Df Residuals:                  270687   BIC:                         1.302e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# column_a    2598.0978     83.300     31.190      0.000    2434.833    2761.363
# ==============================================================================
# Omnibus:                   588748.933   Durbin-Watson:                   1.535
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1968851695.601
# Skew:                          20.159   Prob(JB):                         0.00
# Kurtosis:                     418.859   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_var=df1['beat']
y_var=df1[ 'number']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 number   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     378.1
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           3.71e-84
# Time:                        17:59:34   Log-Likelihood:            -6.5117e+06
# No. Observations:              270688   AIC:                         1.302e+07
# Df Residuals:                  270687   BIC:                         1.302e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beat         4.22e+05   2.17e+04     19.444      0.000    3.79e+05    4.65e+05
# ==============================================================================
# Omnibus:                   588671.673   Durbin-Watson:                   1.534
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1969283908.226
# Skew:                          20.152   Prob(JB):                         0.00
# Kurtosis:                     418.906   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_var=df1['lat']
y_var=df1[ 'beat']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   beat   R-squared:                       0.360
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                 1.520e+05
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):               0.00
# Time:                        17:59:34   Log-Likelihood:            -2.0556e+06
# No. Observations:              270688   AIC:                         4.111e+06
# Df Residuals:                  270687   BIC:                         4.111e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lat           10.6673      0.027    389.834      0.000      10.614      10.721
# ==============================================================================
# Omnibus:                  1402891.836   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   53677122637596.086
# Skew:                         245.608   Prob(JB):                         0.00
# Kurtosis:                   68988.009   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_var=df1['long']
y_var=df1[ 'lat']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    lat   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.057e+11
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):               0.00
# Time:                        17:59:34   Log-Likelihood:             4.0595e+05
# No. Observations:              270688   AIC:                        -8.119e+05
# Df Residuals:                  270687   BIC:                        -8.119e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# long          -0.3999   1.23e-06  -3.25e+05      0.000      -0.400      -0.400
# ==============================================================================
# Omnibus:                      423.133   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              425.437
# Skew:                          -0.095   Prob(JB):                     4.15e-93
# Kurtosis:                       3.036   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.values.reshape(-1,1)

# %%
labels = y_train.values.reshape(-1,1)

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.00018583565799834556

# %%
x=df1.iloc[:,0:6]
y=df1.iloc[:,-1]

# %%
x
# Out:
#         column_a        number   beat       lat      long
# 0              0  1.030400e+08  509.0  33.77101 -84.38895
# 1              1  1.030401e+08  401.0  33.74057 -84.41680
# 2              2  1.030402e+08  301.0  33.71803 -84.40774
# 3              3  1.030402e+08  307.0  33.70731 -84.39674
# 4              4  1.030403e+08  604.0  33.75947 -84.36626
# 5              5  1.030403e+08  205.0  33.82838 -84.40133
# 6              6  1.030403e+08  410.0  33.70537 -84.45498
# 7              7  1.030404e+08  410.0  33.70121 -84.45724
# 8              8  1.030404e+08  201.0  33.83193 -84.42627
# 9              9  1.030404e+08  509.0  33.76040 -84.38746
# 10            10  1.030404e+08  602.0  33.76309 -84.35160
# 11            11  1.030405e+08  109.0  33.77725 -84.46072
# 12            12  1.030405e+08  210.0  33.84922 -84.36056
# 13            13  1.030405e+08  211.0  33.82674 -84.36131
# 14            14  1.030406e+08  508.0  33.75946 -84.38769
# 15            15  1.030406e+08  509.0  33.77101 -84.38895
# 16            16  1.030409e+08  303.0  33.74075 -84.39454
# 17            17  1.030409e+08  308.0  33.70604 -84.35916
# 18            18  1.030409e+08  211.0  33.82543 -84.36706
# 19            19  1.030410e+08  605.0  33.73611 -84.37812
# 20            20  1.030410e+08  609.0  33.75795 -84.34501
# 26       -84.40378
# 27       -84.38477
# 28       -84.40755
# 29       -84.37852
#             ...
# 270658   -84.40118
# 270659   -84.46475
# 270660   -84.33122
# 270661   -84.39376
# 270662   -84.37225
# 270663   -84.38850
# 270664   -84.37025
# 270665   -84.38733
# 270666   -84.50762
# 270667   -84.38741
# 270668   -84.52990
# 270669   -84.42299
# 270670   -84.49864
# 270671   -84.34904
# 270672   -84.40793
# 270673   -84.40102
# 270674   -84.36212
# 270675   -84.51026
# 270676   -84.44770
# 270677   -84.44465
# 270678   -84.40905
# 270679   -84.41532
# 270680   -84.36817
# 270681   -84.35274
# 270682   -84.38777
# 270683   -84.34741
# 270684   -84.40013
# 270685   -84.44204
# 270686   -84.32600
# 270687   -84.48138
# Name: long, Length: 270688, dtype: float64

# %%
from sklearn import preprocessing
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# array([[0.00000000e+00, 1.78127829e-04, 3.39262418e-03, 7.29784287e-01,
#         6.11723276e-01],
#        [3.69430375e-06, 1.78128017e-04, 2.59435967e-03, 6.58333920e-01,
#         5.06266803e-01],
#        [7.38860751e-06, 1.78128651e-04, 1.85522586e-03, 6.05426848e-01,
#         5.40573289e-01],
#        ...,
#        [9.99992611e-01, 1.15957465e-04, 0.00000000e+00, 4.23866864e-01,
#         4.10693324e-01],
#        [9.99996306e-01, 1.15915327e-04, 4.13914933e-03, 6.89247236e-01,
#         8.50088985e-01],
#        [1.00000000e+00, 5.42158320e-01, 2.62392502e-03, 6.89834049e-01,
#         2.61728956e-01]])

# %%
x_var=df1[['column_a', 'number', 'beat', 'lat', 'long']]
y_var=df1['long' ]
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   long   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.710e+27
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):               0.00
# Time:                        17:59:38   Log-Likelihood:             7.5866e+06
# No. Observations:              270688   AIC:                        -1.517e+07
# Df Residuals:                  270683   BIC:                        -1.517e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# column_a    1.626e-18      4e-21    406.069      0.000    1.62e-18    1.63e-18
# number     -5.962e-25   4.62e-26    -12.892      0.000   -6.87e-25   -5.06e-25
# beat         1.78e-16   6.52e-19    273.186      0.000    1.77e-16    1.79e-16
# lat         2.487e-14    5.8e-15      4.288      0.000    1.35e-14    3.62e-14
# long           1.0000   2.32e-15   4.31e+14      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                   809952.822   Durbin-Watson:                   0.552
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     502855379627.502
# Skew:                         -42.619   Prob(JB):                         0.00
# Kurtosis:                    6679.630   Cond. No.                     1.35e+11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Splitting the dataset into Training set and Test set
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.iloc[:,:].values

# %%
features
# Out:
# array([[ 2.01819000e+05,  1.01861130e+08,  6.03000000e+02,
#          3.37711700e+01, -8.43802500e+01],
#        [ 4.24200000e+03,  1.12951287e+08,  5.03000000e+02,
#          3.37805000e+01, -8.43875200e+01],
#        [ 2.15471000e+05,  1.52031431e+08,  5.08000000e+02,
#          3.37598100e+01, -8.43916800e+01],
#        ...,
#        [ 1.24605000e+05,  1.50682838e+08,  2.04000000e+02,
#          3.38038800e+01, -8.44127800e+01],
#        [ 2.04630000e+04,  9.29915860e+07,  1.12000000e+02,
#          3.37773500e+01, -8.44774100e+01],
#        [ 1.86380000e+04,  1.62891973e+08,  2.11000000e+02,
#          3.38274200e+01, -8.43653200e+01]])

# %%
labels = y_train.iloc[:].values

# %%
labels=labels

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 1.0

# %%
predictions = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score


print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [-1.14331437e-19  2.45546305e-27 -1.20680913e-20  4.24686634e-16
#   1.00000000e+00]
# Intercept: 7.105427357601002e-14
#
#
# The model performance
# --------------------------------------
# RMSE is 1.0446483069496585e-14
# R2 score is 1.0

# %%
#Build a Logistic Regression Model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
lr = LogisticRegression()
y=lr.fit(x_train, y_train)
#lr.fit(x_train,y_train)#dichomous or binary classification.
#lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
#lr_proba = cross_val_predict(lr, x_train_std, y_train, cv=3, method='predict_proba')
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-df30069a7f2d> in <module>
#       3 from sklearn.model_selection import cross_val_score
#       4 lr = LogisticRegression()
# ----> 5 y=lr.fit(x_train, y_train)
#       6 #lr.fit(x_train,y_train)#dichomous or binary classification.
#       7 #lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1285                          accept_large_sparse=solver != 'liblinear')
# -> 1286         check_classification_targets(y)
#    1287         self.classes_ = np.unique(y)
#    1288         n_samples, n_features = X.shape
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     169     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     170                       'multilabel-indicator', 'multilabel-sequences']:
# --> 171         raise ValueError("Unknown label type: %r" % y_type)
#     172
#     173
#
# ValueError: Unknown label type: 'continuous'

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
decision_tree_model = DecisionTreeRegressor()
decision_tree_fit = decision_tree_model.fit(x_train, y_train)
#life_features_train, life_features_test, life_labels_train, life_labels_test
#x_train, x_test, y_train, y_test 
decision_tree_score = cross_val_score(decision_tree_fit, x_train, y_train, cv = 5)
print("mean cross validation score: %.2f"  % np.mean(decision_tree_score))
print("score without cv: %.2f" % decision_tree_fit.score(x_train, y_train))
print("R^2 score on the test data %.2f"% r2_score(y_test, decision_tree_fit.predict(x_test)))
# Out:
# mean cross validation score: 1.00
# score without cv: 1.00
# R^2 score on the test data 1.00

# %%
y_pred = decision_tree_model.predict(x_test)
#from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

#print("\nAccuracy score: %f" %(accuracy_score(y_test,y_pred) * 100))
#print("Recall score : %f" %(recall_score(y_test, y_pred) * 100))
#print("ROC score : %f\n" %(roc_auc_score(y_test, y_pred) * 100))
#print(confusion_matrix(y_test, y_pred)) #27 out of 114 have no cancer as told by the model.11 told that doctor predicted it has cancer but machine prididcted as it does not have cancer.
#1 data is there where doctor interpre

# %%
y_pred = decision_tree_model.predict(x_test)
#life_features_train, life_features_test, life_labels_train, life_labels_test
#x_train, x_test, y_train, y_test 
accuracy=decision_tree_model.score(x_test,y_test)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.9999788410868612

# %%
y_pred
# Out:
# array([-84.44066669, -84.48323065, -84.38712103, ..., -84.396276  ,
#        -84.44396878, -84.33548095])

# %%
y_test
# Out:
# 181861   -84.44077
# 12420    -84.48336
# 178242   -84.38723
# 150927   -84.41349
# 124970   -84.49773
# 122944   -84.40617
# 108400   -84.39184
# 1279     -84.41685
# 259518   -84.34619
# 21865    -84.37234
# 203867   -84.29310
# 223512   -84.37774
# 203045   -84.42756
# 67701    -84.35388
# 247702   -84.38744
# 21114    -84.39891
# 191830   -84.39339
# 95476    -84.40649
# 104142   -84.36358
# 30734    -84.41278
# 244270   -84.39810
# 79114    -84.47792
# 108033   -84.41421
# 136919   -84.35014
# 154625   -84.40177
# 134847   -84.34863
# 110249   -84.36963
# 37152    -84.33885
# 166092   -84.44713
# 45573    -84.39863
#             ...
# 16336    -84.41457
# 255511   -84.50299
# 27289    -84.41167
# 243444   -84.43276
# 211090   -84.38023
# 244705   -84.53736
# 228901   -84.38403
# 217686   -84.38805
# 19458    -84.45173
# 196579   -84.49032
# 234765   -84.32598
# 89978    -84.36212
# 248772   -84.37430
# 219688   -84.38124
# 787      -84.40069
# 103704   -84.49389
# 39247    -84.36722
# 35253    -84.36161
# 98720    -84.41457
# 197607   -84.38589
# 133543   -84.47815
# 195532   -84.47023
# 131309   -84.35165
# 166834   -84.35878
# 109953   -84.43241
# 65561    -84.38407
# 47020    -84.43168
# 61492    -84.39636
# 194755   -84.44423
# 146874   -84.33561
# Name: long, Length: 27069, dtype: float64

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print("\nAccuracy score: %f" %(decision_tree_model.score(x_test,y_test) * 100))
# Out:
# Accuracy score: 99.997884

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor()
random_forest_fit = random_forest_model.fit(x_train, y_train)
random_forest_score = cross_val_score(random_forest_fit, x_train, y_train, cv = 5)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
y_predict = random_forest_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print("\nAccuracy score of random forest is: %f" %(random_forest_model.score(x_test,y_test) * 100))
# Out:
# Accuracy score of random forest is: 99.998785
